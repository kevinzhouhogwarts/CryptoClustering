# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
import holoviews as hv
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e69a72f4-3bac-4402-90b0-af0b81332156" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                           1.08388                     7.60278
# ethereum                          0.22392                    10.38134
# tether                           -0.21173                     0.04935
# ripple                           -0.37819                    -0.60926
# bitcoin-cash                      2.90585                    17.09717
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                           6.57509                      7.67258
# ethereum                          4.80849                      0.13169
# tether                            0.00640                     -0.04237
# ripple                            2.24984                      0.23455
# bitcoin-cash                     14.75334                     15.74903
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Generate summary statistics for the behavior of each price change y-variable 
df_market_data.describe()

column_headers = df_market_data.columns

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
from sklearn.preprocessing import StandardScaler

scaled_array = StandardScaler().fit_transform(df_market_data)
scaled_array
# Out:
# array([[ 5.08529366e-01,  4.93193071e-01,  7.72200433e-01,
#          2.35459633e-01, -6.74950963e-02, -3.55953481e-01,
#         -2.51636882e-01],
#        [ 1.85445894e-01,  9.34445040e-01,  5.58692121e-01,
#         -5.43409317e-02, -2.73482725e-01, -1.15759474e-01,
#         -1.99352110e-01],
#        [ 2.17739616e-02, -7.06336853e-01, -2.16804207e-02,
#         -6.10301536e-02,  8.00452481e-03, -5.50246924e-01,
#         -2.82060506e-01],
#        [-4.07643829e-02, -8.10928066e-01,  2.49457974e-01,
#         -5.03879651e-02, -3.73164019e-01, -4.58258816e-01,
#         -2.95546142e-01],
#        [ 1.19303608e+00,  2.00095907e+00,  1.76061001e+00,
#          5.45842065e-01, -2.91202870e-01, -4.99847761e-01,
#         -2.70316950e-01],
#        [ 8.91870708e-01,  1.32729453e+00,  8.00214184e-01,
#         -5.71478992e-02,  7.78653106e-01, -1.88231917e-01,
#         -2.25532605e-01],
#        [ 1.13972400e-02,  2.57225091e+00,  1.10164693e+00,
# ...

# %%
# Create a DataFrame with the scaled data
df_scaled_data = pd.DataFrame(scaled_array, columns=column_headers)

# Copy the crypto names from the original DataFrame
index = df_market_data.index

df_scaled_data.insert(0, "coin_id", index, allow_duplicates=True)
df_scaled_data = df_scaled_data.set_index("coin_id")
df_scaled_data.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
for i in k:
    model = KMeans(n_clusters = i, random_state = 1)
    model.fit(df_scaled_data)
    inertia.append(model.inertia_)
inertia
# Out:
# C:\Users\rfqwx\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\rfqwx\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\rfqwx\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
dictionary = {
    "Number of Clusters": k,
    "Inertia": inertia
}

# Create a DataFrame with the data to plot the Elbow curve
df_to_plot = pd.DataFrame(dictionary)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
pre_pca_elbow_plot = df_to_plot.hvplot.line(
    x = "Number of Clusters",
    y = "Inertia",
    title = "Elbow Curve",
    color = "blue",
    label = "pre-PCA",
    xticks = k
)
pre_pca_elbow_plot
# Out:
# :Curve   [Number of Clusters]   (Inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** 4 (Visually obvious from the graph that 4 is the point of diminishing returns)

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters = 4, random_state = 1)

# %%
# Fit the K-Means model using the scaled DataFrame
model.fit(df_scaled_data)
# Out:
# C:\Users\rfqwx\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame
cluster_labels = model.predict(df_scaled_data)

# Print the resulting array of cluster values.
cluster_labels
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 3, 2, 0, 0, 1, 0, 0, 0, 0])

# %%
# Create a copy of the scaled DataFrame
df_scaled_data_copy = df_scaled_data.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters
df_scaled_data_copy["cluster_labels"] = cluster_labels

# Display the copy of the scaled DataFrame
df_scaled_data_copy.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
pre_pca_cluster_plot = df_scaled_data_copy.hvplot.scatter(
    x = "price_change_percentage_24h",
    y = "price_change_percentage_7d",
    by = "cluster_labels",
    title = "Clustering Projection onto Price Change 24h vs 7d",
    hover_cols = "coin_id"
)
pre_pca_cluster_plot
# Out:
# :NdOverlay   [cluster_labels]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
model_pca = PCA(n_components = 3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.
array_pca = model_pca.fit_transform(df_scaled_data)
# View the scaled PCA data
array_pca
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527],
#        [-0.51653377,  1.38837748,  0.80407131],
#        [-0.45071134,  0.51769912,  2.84614316],
#        [-0.34559977,  0.72943939,  1.47801284],
#        [-0.64946792,  0.43216514,  0.60030286],
#        [-0.75901394, -0.20119979, -0.21765292],
#        [-0.24819846, -1.37625159, -1.46202571],
#        [-0.43840762, -0.17533654, -0.6633884 ],
#        [-0.69342533, -0.47381462, -0.52759693],
#        [ 0.06049915,  2.90940385,  1.49857131],
#        [-0.39335243, -0.10819197, -0.01275608],
#        [-0.79617564, -0.49440875,  1.08281169],
#        [ 0.06407452, -1.26982514, -1.09882928],
#        [-0.48901506, -0.73271912, -0.06254323],
#        [-0.3062723 ,  0.70341515,  1.71422359],
#        [-0.51352775, -0.14280239, -0.65656583],
# ...

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.
explained_variance_ratios = model_pca.explained_variance_ratio_
print(explained_variance_ratios)

cumsum = sum(model_pca.explained_variance_ratio_)
cumsum
# Out:
# [0.3719856  0.34700813 0.17603793]
# 0.895031657030984

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** 89.5%

# %%
# Create a new DataFrame with the PCA data.
df_pca = pd.DataFrame(array_pca, columns = ["feature_0", "feature_1", "feature_2"])

# Copy the crypto names from the original scaled DataFrame
index = df_scaled_data.index

df_pca.insert(0, "coin_id", index, allow_duplicates=True)
df_pca = df_pca.set_index("coin_id")
df_pca.head()
# Out:
#               feature_0  feature_1  feature_2
# coin_id
# bitcoin       -0.600667   0.842760   0.461595
# ethereum      -0.458261   0.458466   0.952877
# tether        -0.433070  -0.168126  -0.641752
# ripple        -0.471835  -0.222660  -0.479053
# bitcoin-cash  -1.157800   2.041209   1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using `df_market_data_pca`
# 3. Append the model.inertia_ to the inertia list
for i in k:
    model = KMeans(n_clusters = i, random_state = 1)
    model.fit(df_pca)
    inertia.append(model.inertia_)
inertia
# Out:
# C:\Users\rfqwx\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\rfqwx\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\rfqwx\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
dictionary = {
    "Number of Clusters": k,
    "Inertia": inertia
}

# Create a DataFrame with the data to plot the Elbow curve
df_to_plot_pca = pd.DataFrame(dictionary)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
post_pca_elbow_plot = df_to_plot_pca.hvplot.line(
    x = "Number of Clusters",
    y = "Inertia",
    title = "Elbow Curve",
    color = "red",
    label = "post-PCA",
    xticks = k
)
post_pca_elbow_plot
# Out:
# :Curve   [Number of Clusters]   (Inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters = 4, random_state = 1)

# %%
# Fit the K-Means model using the PCA data
model.fit(df_pca)
# Out:
# C:\Users\rfqwx\.conda\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame
cluster_labels = model.predict(df_pca)

# Print the resulting array of cluster values.
cluster_labels
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 3, 2, 0, 0, 1, 0, 0, 0, 0])

# %%
# Create a copy of the scaled PCA DataFrame
df_pca_copy = df_pca.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters
df_pca_copy["cluster_labels"] = cluster_labels

# Display the copy of the scaled PCA DataFrame
df_pca_copy
# Out:
#                       feature_0  feature_1  feature_2  cluster_labels
# coin_id
# bitcoin               -0.600667   0.842760   0.461595               2
# ethereum              -0.458261   0.458466   0.952877               2
# tether                -0.433070  -0.168126  -0.641752               0
# ripple                -0.471835  -0.222660  -0.479053               0
# bitcoin-cash          -1.157800   2.041209   1.859715               2
# binancecoin           -0.516534   1.388377   0.804071               2
# chainlink             -0.450711   0.517699   2.846143               2
# cardano               -0.345600   0.729439   1.478013               2
# litecoin              -0.649468   0.432165   0.600303               2
# bitcoin-cash-sv       -0.759014  -0.201200  -0.217653               0
# crypto-com-chain      -0.248198  -1.376252  -1.462026               0
# usd-coin              -0.438408  -0.175337  -0.663388               0
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
# pca_plot1 = df_pca_copy.hvplot.scatter(
#     x = "feature_0",
#     y = "feature_1",
#     title = "Clustering Projection onto Two Principal Components",
#     hover_cols = "coin_id",
#     marker = "triangle"
# )

pca_plot2 = df_pca_copy.hvplot.scatter(
    x = "feature_1",
    y = "feature_2",
    by = "cluster_labels",
    title = "Clustering Projection onto Two Principal Components",
    hover_cols = "coin_id",
    marker = "x"
)
pca_plot2

# pca_plot3 = df_pca_copy.hvplot.scatter(
#     x = "feature_0",
#     y = "feature_2",
#     title = "Clustering Projection onto Two Principal Components",
#     hover_cols = "coin_id",
#     marker = "triangle"
# )

# layout = hv.Layout([plot1, plot2, plot3]).cols(1)
# layout
# Out:
# :NdOverlay   [cluster_labels]
#    :Scatter   [feature_1]   (feature_2,coin_id)

# %%
# Plot all three clustering projections for the post PCA dataset
test_1 = df_pca_copy.hvplot.scatter(
    x = "feature_0",
    y = "feature_1",
    by = "cluster_labels",
    title = "Clustering Projection onto Two Principal Components",
    hover_cols = "coin_id"
)

test_2 = df_pca_copy.hvplot.scatter(
    x = "feature_1",
    y = "feature_2",
    by = "cluster_labels",
    title = "Clustering Projection onto Two Principal Components",
    hover_cols = "coin_id"
)

test_3 = df_pca_copy.hvplot.scatter(
    x = "feature_0",
    y = "feature_2",
    by = "cluster_labels",
    title = "Clustering Projection onto Two Principal Components",
    hover_cols = "coin_id"
)

layout = hv.Layout([test_1, test_2, test_3]).cols(1)
layout
# Out:
# :Layout
#    .NdOverlay.I   :NdOverlay   [cluster_labels]
#       :Scatter   [feature_0]   (feature_1,coin_id)
#    .NdOverlay.II  :NdOverlay   [cluster_labels]
#       :Scatter   [feature_1]   (feature_2,coin_id)
#    .NdOverlay.III :NdOverlay   [cluster_labels]
#       :Scatter   [feature_0]   (feature_2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Overlay composite plot to contrast the Elbow curves
composite_elbow_plot = pre_pca_elbow_plot * post_pca_elbow_plot

composite_elbow_plot.opts(
    title='Elbow Curve Comparison',
    xlabel='Number of Clusters',
    ylabel='Inertia',
    legend_position='top_right'
)
composite_elbow_plot
# Out:
# :Overlay
#    .Curve.Pre_hyphen_minus_PCA  :Curve   [Number of Clusters]   (Inertia)
#    .Curve.Post_hyphen_minus_PCA :Curve   [Number of Clusters]   (Inertia)

# %%
# Side-by-side composite plot to contrast the Elbow curves
composite_elbow_plot_side = (pre_pca_elbow_plot.opts(width=400, height=300) + post_pca_elbow_plot.opts(width=400, height=300))
composite_elbow_plot_side
# Out:
# :Layout
#    .Curve.Pre_hyphen_minus_PCA  :Curve   [Number of Clusters]   (Inertia)
#    .Curve.Post_hyphen_minus_PCA :Curve   [Number of Clusters]   (Inertia)

# %%
# Overlay composite plot to contrast the clusters
composite_cluster_plot = pre_pca_cluster_plot * pca_plot2
composite_cluster_plot

composite_cluster_plot.opts(
    title = "Clustering, pre-PCA and post-PCA",
    xlabel = "Price Change 24h/feature_1",
    ylabel = "Price Change 7d/feature_2",
    legend_position = "top_right"
)
# Out:
# :Overlay
#    .NdOverlay.I  :NdOverlay   [cluster_labels]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [cluster_labels]
#       :Scatter   [feature_1]   (feature_2,coin_id)

# %%
# Side-by-side composite plot to contrast the clusters
composite_cluster_plot_side = pre_pca_cluster_plot.opts(width=400, height=300, show_legend=False) + pca_plot2.opts(width=400, height=300, show_legend=False)
composite_cluster_plot_side
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [cluster_labels]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [cluster_labels]
#       :Scatter   [feature_1]   (feature_2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** Visually, the clustering in the chosen directions (24h/7d and PCA1/PCA2) appears similar, especially the intra-cluster compactness. However, separation between clusters seems slightly improved, especially for the two outlier data points in this sample dataset. In particular, the Celsius Degree token datapoint was able to achieve meaningful separation in all three clustering projections (PCA0/PCA1, PCA1/PCA2, PCA0/PCA2).
